# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (1.2.19)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.48-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (0.7.17)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain_community) (1.26.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.23.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: certifi in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/admin/ENTER/envs/tfq_env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 9.6 MB/s  0:00:00 eta 0:00:01
# Downloading aiohttp-3.13.3-cp310-cp310-macosx_11_0_arm64.whl (491 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.3 MB/s  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp310-cp310-macosx_11_0_arm64.whl (44 kB)
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.48-cp310-cp310-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.1 MB/s  0:00:00 eta 0:00:01
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp310-cp310-macosx_11_0_arm64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-macosx_11_0_arm64.whl (49 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp310-cp310-macosx_11_0_arm64.whl (47 kB)
# Installing collected packages: SQLAlchemy, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, async-timeout, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [langchain_community]ngchain_community]
# Successfully installed SQLAlchemy-2.0.48 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 async-timeout-4.0.3 attrs-25.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-classic-1.0.3 langchain-text-splitters-1.1.1 langchain_community-0.4.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.13.1 typing-inspect-0.9.0 yarl-1.23.0

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# /var/folders/gl/fjrfsb3j7gb_g4xl6h7zpyp80000gn/T/ipykernel_4830/1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'All The ChatGPT Updates & Timeline - AutoGPT',
#   'url': 'https://autogpt.net/chatgpt-updates/',
#   'content': 'GPT-5.2-Codex Variant: A specialized coding-focused variant (released January 14, 2026) with context compaction and state-of-the-art scores on SWE-Bench Pro and Terminal-Bench 2.0.\n "Code Red" Accelerated Launch: Media widely reported an internal OpenAI memo, triggered by Google\'s Gemini 3 Pro gaining dominance, accelerated GPT-5.2\'s release from its originally planned late-December windows.',
#   'score': 0.9996049},
#  {'title': 'ChatGPT by OpenAI - Release Notes - March 2026 Latest Updates',
#   'url': 'https://releasebot.io/updates/openai/chatgpt',
#   'content': 'We’re rolling out an update to GPT-5.3 Instant that improves follow-up tone and reduces teaser-style phrasing in responses (e.g., “If you want…”, “You’ll never believe…”, “I can tell you these three things that…”).\n\nOriginal sourceReport a problem\n\n   \nMar 11, 2026 \n       Date parsed from source:  Mar 11, 2026 \n       First seen by Releasebot:  Mar 12, 2026\n       Modified by Releasebot:  Mar 17, 2026 \n\nImage 4: OpenAI logo\n\nChatGPT by OpenAI\n\nMarch 11, 2026\n\nChatGPT updates deprecate GPT-5.1 models and automatically route conversations to GPT-5.3/5.4 equivalents.\n\nAs of March 11, 2026, GPT-5.1 models are no longer available in ChatGPT. [...] ChatGPT by OpenAI\n\nFebruary 13, 2026\n\nOpenAI retires GPT-4o and legacy models and rolls out ChatGPT updates. Users get up to 20-file uploads, broader file type support, cleaner copy via Cmd+A, quick tools on Android, a simplified composer, faster iOS performance, and steadier long chats.\n\n### Retiring GPT-4o and other legacy models\n\nAs previously announced, we have retired GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini from ChatGPT. We are also retiring GPT-5 (Instant and Thinking), as previously announced. There are no API changes at this time. For details, see our blog post and Help Center.\n\n### ChatGPT updates: Better file uploads, easier copying, and more reliable long chats\n\nWeb [...] This applies to GPT-5.1 Instant, GPT-5.1 Thinking, and GPT-5.1 Pro. Existing conversations that used GPT-5.1 will automatically continue on the corresponding current model: GPT-5.3 Instant, GPT-5.4 Thinking, or GPT-5.4 Pro.\n\nOriginal sourceReport a problem\n\n    All of your release notes in one feed\n\nJoin Releasebot and get updates from OpenAI and hundreds of other software products.\n\nCreate accountGet updates with:RSSEmailAPICSVMCPSlackn8nZapier    \n   \nMar 10, 2026 \n       Date parsed from source:  Mar 10, 2026 \n       First seen by Releasebot:  Mar 11, 2026\n       Modified by Releasebot:  Mar 17, 2026 \n\nImage 5: OpenAI logo\n\nChatGPT by OpenAI\n\nMarch 10, 2026',
#   'score': 0.9992679}]

# %%
for r in results:
    print(r['content'])
# Out:
# GPT-5.2-Codex Variant: A specialized coding-focused variant (released January 14, 2026) with context compaction and state-of-the-art scores on SWE-Bench Pro and Terminal-Bench 2.0.
#  "Code Red" Accelerated Launch: Media widely reported an internal OpenAI memo, triggered by Google's Gemini 3 Pro gaining dominance, accelerated GPT-5.2's release from its originally planned late-December windows.
# We’re rolling out an update to GPT-5.3 Instant that improves follow-up tone and reduces teaser-style phrasing in responses (e.g., “If you want…”, “You’ll never believe…”, “I can tell you these three things that…”).
#
# Original sourceReport a problem
#
#
# Mar 11, 2026
#        Date parsed from source:  Mar 11, 2026
#        First seen by Releasebot:  Mar 12, 2026
#        Modified by Releasebot:  Mar 17, 2026
#
# Image 4: OpenAI logo
#
# ChatGPT by OpenAI
#
# March 11, 2026
#
# ChatGPT updates deprecate GPT-5.1 models and automatically route conversations to GPT-5.3/5.4 equivalents.
#
# As of March 11, 2026, GPT-5.1 models are no longer available in ChatGPT. [...] ChatGPT by OpenAI
#
# February 13, 2026
#
# OpenAI retires GPT-4o and legacy models and rolls out ChatGPT updates. Users get up to 20-file uploads, broader file type support, cleaner copy via Cmd+A, quick tools on Android, a simplified composer, faster iOS performance, and steadier long chats.
#
# ### Retiring GPT-4o and other legacy models
#
# As previously announced, we have retired GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini from ChatGPT. We are also retiring GPT-5 (Instant and Thinking), as previously announced. There are no API changes at this time. For details, see our blog post and Help Center.
#
# ### ChatGPT updates: Better file uploads, easier copying, and more reliable long chats
#
# Web [...] This applies to GPT-5.1 Instant, GPT-5.1 Thinking, and GPT-5.1 Pro. Existing conversations that used GPT-5.1 will automatically continue on the corresponding current model: GPT-5.3 Instant, GPT-5.4 Thinking, or GPT-5.4 Pro.
#
# Original sourceReport a problem
#
#     All of your release notes in one feed
#
# Join Releasebot and get updates from OpenAI and hundreds of other software products.
#
# Create accountGet updates with:RSSEmailAPICSVMCPSlackn8nZapier
#
# Mar 10, 2026
#        Date parsed from source:  Mar 10, 2026
#        First seen by Releasebot:  Mar 11, 2026
#        Modified by Releasebot:  Mar 17, 2026
#
# Image 5: OpenAI logo
#
# ChatGPT by OpenAI
#
# March 10, 2026
